# %%
import os
import sys
import networkx as nx
import random
import pyscipopt as sp
import numpy as np
import multiprocessing as md
from functools import partial
import imp

import gisp
import fcmcnf

# %load_ext autoreload 
# %autoreload 2



def distribute(n_instance, n_cpu):
    if n_cpu == 1:
        return [(0, n_instance)]
    
    k = n_instance //( n_cpu -1 )
    r = n_instance % (n_cpu - 1 )
    res = []
    for i in range(n_cpu -1):
        res.append( ((k*i), (k*(i+1))) )
    
    res.append(((n_cpu - 1) *k ,(n_cpu - 1) *k + r ))
    return res

# %%
n_cpu = 40
n_instance = 1000

problem = 'FCMCNF'

data_partition = 'valid'


instance = None
solveInstance = True

exp_dir = f"data/{problem}/"


er_prob = 0.6
whichSet = 'SET2'
setParam = 100.0
alphaE2 = 0.5
timelimit = 7200.0

seed = 5000

min_n = 15
max_n = 20

min_n_nodes = 20
max_n_nodes = 20

min_n_arcs = 80
max_n_arcs = 100

min_n_commodities = 20
max_n_commodities = 30

if problem == 'FCMCNF':
    min_n, max_n = min_n_arcs, max_n_arcs




assert exp_dir is not None
if instance is None:
    assert min_n is not None
    assert max_n is not None

exp_dir = exp_dir + data_partition
lp_dir= os.path.join(os.path.abspath('.'), exp_dir)
try:
    os.makedirs(lp_dir)
except FileExistsError:
    ""

print(f"Summary for {problem} generation")
print(f"n_instance    :     {n_instance}")
print(f"size interval :     {min_n, max_n}")
print(f"n_cpu         :     {n_cpu} ")
print(f"solve         :     {solveInstance}")
print(f"saving dir    :     {lp_dir}")



cpu_count = md.cpu_count()//2 if n_cpu == None else n_cpu
# Out:
# Summary for FCMCNF generation
# n_instance    :     1000
# size interval :     (80, 100)
# n_cpu         :     40
# solve         :     True
# saving dir    :     /local_workspace/labaabde/learn2selectnodes/problem_generation/data/FCMCNF/valid

# %%
if problem == 'GISP':
    processes = [  md.Process(name=f"worker {p}", target=partial(gisp.generate_instances,
                                                                  seed + p1, 
                                                                  seed + p2, 
                                                                  whichSet, 
                                                                  setParam, 
                                                                  alphaE2, 
                                                                  min_n, 
                                                                  max_n, 
                                                                  er_prob, 
                                                                  instance, 
                                                                  lp_dir, 
                                                                  solveInstance))


                 for p,(p1,p2) in enumerate(distribute(n_instance, n_cpu)) ]

elif problem == 'FCMCNF':

#=============================================================================
    processes = [  md.Process(name=f"worker {p}", target=partial(fcmcnf.generate_instances,
                                                                  seed + p1, 
                                                                  seed + p2, 
                                                                  min_n_nodes,
                                                                  max_n_nodes,
                                                                  min_n_arcs,
                                                                  max_n_arcs,
                                                                  min_n_commodities,
                                                                  max_n_commodities,
                                                                  lp_dir, 
                                                                  solveInstance))


                  for p,(p1,p2) in enumerate(distribute(n_instance, n_cpu)) ]

#=============================================================================
    #generate_fcmcnf.generate_instances(0, n_instance, min_n_nodes, max_n_nodes, min_n_arcs, max_n_arcs, min_n_commodities, max_n_commodities, lp_dir, solveInstance)



a = list(map(lambda p: p.start(), processes)) #run processes
b = list(map(lambda p: p.join(), processes)) #join processes
print('Generated')
# Out:
# DiGraph with 20 nodes and 92 edgesDiGraph with 20 nodes and 87 edges
#
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 81 edgesDiGraph with 20 nodes and 94 edges
#
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 99 edgesDiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 82 edges
#
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 99 edgesDiGraph with 20 nodes and 84 edges
#
# DiGraph with 20 nodes and 80 edgesDiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 87 edges
#
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 90 edgesDiGraph with 20 nodes and 93 edges
#
# DiGraph with 20 nodes and 89 edgesDiGraph with 20 nodes and 93 edgesDiGraph with 20 nodes and 89 edges
#
#
# DiGraph with 20 nodes and 91 edgesDiGraph with 20 nodes and 95 edgesDiGraph with 20 nodes and 86 edgesDiGraph with 20 nodes and 98 edgesDiGraph with 20 nodes and 85 edgesDiGraph with 20 nodes and 99 edges
#
#
#
#
#
# DiGraph with 20 nodes and 89 edgesDiGraph with 20 nodes and 98 edges
#
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 87 edgesDiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 90 edges
#
# DiGraph with 20 nodes and 90 edgesDiGraph with 20 nodes and 94 edgesDiGraph with 20 nodes and 94 edges
#
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 90 edges
#
# DiGraph with 20 nodes and 80 edges
#
# DiGraph with 20 nodes and 95 edgesDiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 91 edgesDiGraph with 20 nodes and 88 edgesDiGraph with 20 nodes and 92 edges
#
# DiGraph with 20 nodes and 87 edgesDiGraph with 20 nodes and 90 edgesDiGraph with 20 nodes and 92 edgesDiGraph with 20 nodes and 86 edgesDiGraph with 20 nodes and 82 edgesDiGraph with 20 nodes and 96 edgesDiGraph with 20 nodes and 100 edgesDiGraph with 20 nodes and 100 edgesDiGraph with 20 nodes and 88 edgesDiGraph with 20 nodes and 91 edges
#
#
#
#
#
#
#
#
#
#
# DiGraph with 20 nodes and 100 edgesDiGraph with 20 nodes and 88 edgesDiGraph with 20 nodes and 86 edgesDiGraph with 20 nodes and 80 edgesDiGraph with 20 nodes and 94 edgesDiGraph with 20 nodes and 89 edgesDiGraph with 20 nodes and 80 edges
#
#
#
#
#
#
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 83 edgesDiGraph with 20 nodes and 98 edgesDiGraph with 20 nodes and 96 edges
#
#
# DiGraph with 20 nodes and 84 edgesDiGraph with 20 nodes and 87 edgesDiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 94 edges
#
#
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 100 edgesDiGraph with 20 nodes and 90 edgesDiGraph with 20 nodes and 85 edges
#
#
# DiGraph with 20 nodes and 98 edgesDiGraph with 20 nodes and 88 edgesDiGraph with 20 nodes and 82 edges
#
#
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 81 edgesDiGraph with 20 nodes and 91 edges
#
# DiGraph with 20 nodes and 90 edgesDiGraph with 20 nodes and 98 edges
#
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 98 edgesDiGraph with 20 nodes and 82 edges
#
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 99 edgesDiGraph with 20 nodes and 84 edges
#
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 96 edgesDiGraph with 20 nodes and 92 edges
#
# DiGraph with 20 nodes and 82 edgesDiGraph with 20 nodes and 87 edges
#
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 88 edgesDiGraph with 20 nodes and 87 edges
#
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 85 edgesDiGraph with 20 nodes and 87 edges
#
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 99 edgesDiGraph with 20 nodes and 81 edges
#
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 85 edgesDiGraph with 20 nodes and 81 edges
#
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edgesDiGraph with 20 nodes and 81 edges
#
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 97 edgesDiGraph with 20 nodes and 85 edges
#
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 88 edgesDiGraph with 20 nodes and 94 edges
#
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 86 edgesDiGraph with 20 nodes and 91 edges
#
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 86 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 98 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 94 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 96 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 91 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 97 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 84 edges
# DiGraph with 20 nodes and 82 edges
# DiGraph with 20 nodes and 95 edges
# DiGraph with 20 nodes and 100 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 83 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 89 edges
# DiGraph with 20 nodes and 80 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 85 edges
# DiGraph with 20 nodes and 99 edges
# DiGraph with 20 nodes and 88 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 87 edges
# DiGraph with 20 nodes and 81 edges
# DiGraph with 20 nodes and 92 edges
# DiGraph with 20 nodes and 90 edges
# DiGraph with 20 nodes and 93 edges
# DiGraph with 20 nodes and 93 edges
# Generated
