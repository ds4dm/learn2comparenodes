# %%
import os
import sys
import networkx as nx
import random
import pyscipopt as sp
import numpy as np
import multiprocessing as md
from functools import partial
import imp

import gisp
import fcmcnf

# %load_ext autoreload 
# %autoreload 2



def distribute(n_instance, n_cpu):
    if n_cpu == 1:
        return [(0, n_instance)]
    
    k = n_instance //( n_cpu -1 )
    r = n_instance % (n_cpu - 1 )
    res = []
    for i in range(n_cpu -1):
        res.append( ((k*i), (k*(i+1))) )
    
    res.append(((n_cpu - 1) *k ,(n_cpu - 1) *k + r ))
    return res
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n_cpu = 8
n_instance = 250

problem = 'FCMCNF'

data_partition = 'test'


instance = None
solveInstance = True

exp_dir = f"data/{problem}/"


er_prob = 0.6
whichSet = 'SET2'
setParam = 100.0
alphaE2 = 0.5
timelimit = 7200.0

seed = 4312

min_n = 25
max_n = 30

min_n_commodities = max_n
max_n_commodities = int(1.5*max_n)


assert exp_dir is not None
if instance is None:
    assert min_n is not None
    assert max_n is not None

exp_dir = exp_dir + data_partition
lp_dir= os.path.join(os.path.abspath('.'), exp_dir)
try:
    os.makedirs(lp_dir)
except FileExistsError:
    ""

print(f"Summary for {problem} generation")
print(f"n_instance    :     {n_instance}")
print(f"size interval :     {min_n, max_n}")
print(f"n_cpu         :     {n_cpu} ")
print(f"solve         :     {solveInstance}")
print(f"saving dir    :     {lp_dir}")



cpu_count = md.cpu_count()//2 if n_cpu == None else n_cpu
# Out:
# Summary for FCMCNF generation
# n_instance    :     250
# size interval :     (25, 30)
# n_cpu         :     8
# solve         :     True
# saving dir    :     /local_workspace/labaabde/learn2selectnodes/problem_generation/data/FCMCNF/test

# %%
if problem == 'GISP':
    processes = [  md.Process(name=f"worker {p}", target=partial(gisp.generate_instances,
                                                                  seed + p1, 
                                                                  seed + p2, 
                                                                  whichSet, 
                                                                  setParam, 
                                                                  alphaE2, 
                                                                  min_n, 
                                                                  max_n, 
                                                                  er_prob, 
                                                                  instance, 
                                                                  lp_dir, 
                                                                  solveInstance))


                 for p,(p1,p2) in enumerate(distribute(n_instance, n_cpu)) ]

elif problem == 'FCMCNF':

#=============================================================================
    processes = [  md.Process(name=f"worker {p}", target=partial(fcmcnf.generate_instances,
                                                                  seed + p1, 
                                                                  seed + p2, 
                                                                  min_n,
                                                                  max_n,
                                                                  min_n_commodities,
                                                                  max_n_commodities,
                                                                  lp_dir, 
                                                                  solveInstance))


                  for p,(p1,p2) in enumerate(distribute(n_instance, n_cpu)) ]

#=============================================================================
    #generate_fcmcnf.generate_instances(0, n_instance, min_n_nodes, max_n_nodes, min_n_arcs, max_n_arcs, min_n_commodities, max_n_commodities, lp_dir, solveInstance)



a = list(map(lambda p: p.start(), processes)) #run processes
b = list(map(lambda p: p.join(), processes)) #join processes
print('Generated')
# Out:
# DiGraph with 19 nodes and 110 edges
# DiGraph with 18 nodes and 95 edges
# DiGraph with 20 nodes and 110 edges
# DiGraph with 20 nodes and 132 edges
# DiGraph with 18 nodes and 93 edges
# DiGraph with 20 nodes and 121 edges
# DiGraph with 16 nodes and 77 edges
# DiGraph with 15 nodes and 78 edges
# 1
# DiGraph with 15 nodes and 73 edges
# 1
# DiGraph with 20 nodes and 138 edges
# 1
# DiGraph with 19 nodes and 123 edges
# 1
# DiGraph with 18 nodes and 92 edges
# 1
# DiGraph with 17 nodes and 91 edges
# 188
# DiGraph with 17 nodes and 83 edges
# 3
# DiGraph with 19 nodes and 111 edges
# 1
# DiGraph with 16 nodes and 74 edges
# 13
# DiGraph with 16 nodes and 84 edges
# 1
# DiGraph with 18 nodes and 102 edges
# 1
# DiGraph with 17 nodes and 82 edges
# 1
# DiGraph with 16 nodes and 71 edges
# 35
# DiGraph with 17 nodes and 84 edges
# 1
# DiGraph with 20 nodes and 139 edges
# 26
# DiGraph with 18 nodes and 108 edges
# 43
# DiGraph with 19 nodes and 109 edges
# 1
# DiGraph with 20 nodes and 125 edges
# 1
# DiGraph with 17 nodes and 91 edges
# 9
# DiGraph with 20 nodes and 127 edges
# 35
# DiGraph with 15 nodes and 67 edges
# 165
# DiGraph with 16 nodes and 83 edges
# 1
# DiGraph with 16 nodes and 81 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 15 nodes and 63 edges
# 428
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 15 nodes and 59 edges
# 1
# DiGraph with 19 nodes and 111 edges
# 1
# DiGraph with 20 nodes and 135 edges
# 1
# DiGraph with 20 nodes and 119 edges
# 1
# DiGraph with 19 nodes and 130 edges
# 29
# DiGraph with 20 nodes and 122 edges
# 1
# DiGraph with 20 nodes and 133 edges
# 1
# DiGraph with 15 nodes and 75 edges
# 5
# DiGraph with 17 nodes and 77 edges
# 1
# DiGraph with 15 nodes and 67 edges
# 1
# DiGraph with 17 nodes and 76 edges
# 1
# DiGraph with 16 nodes and 78 edges
# 321
# DiGraph with 20 nodes and 126 edges
# 103
# DiGraph with 17 nodes and 90 edges
# 812
# DiGraph with 18 nodes and 105 edges
# 316
# DiGraph with 16 nodes and 87 edges
# 41
# DiGraph with 19 nodes and 112 edges
# 1
# DiGraph with 20 nodes and 115 edges
# 14
# DiGraph with 20 nodes and 140 edges
# 474
# DiGraph with 15 nodes and 68 edges
# 71
# DiGraph with 16 nodes and 85 edges
# 9
# DiGraph with 16 nodes and 69 edges
# 1
# DiGraph with 15 nodes and 62 edges
# 207
# DiGraph with 19 nodes and 118 edges
# 3
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 20 nodes and 111 edges
# 1
# DiGraph with 18 nodes and 98 edges
# 63
# DiGraph with 18 nodes and 117 edges
# 49
# DiGraph with 15 nodes and 68 edges
# 94
# DiGraph with 17 nodes and 86 edges
# 1
# DiGraph with 17 nodes and 97 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 79
# DiGraph with 15 nodes and 74 edges
# 0
# DiGraph with 17 nodes and 85 edges
# 1
# DiGraph with 17 nodes and 75 edges
# 97
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 20 nodes and 131 edges
# 1
# 1
# DiGraph with 19 nodes and 115 edges
# 54
# DiGraph with 15 nodes and 68 edges
# 21
# DiGraph with 20 nodes and 116 edges
# 1
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 18 nodes and 97 edges
# 1
# DiGraph with 17 nodes and 87 edges
# 293
# DiGraph with 17 nodes and 88 edges
# 9
# DiGraph with 15 nodes and 72 edges
# 129
# DiGraph with 17 nodes and 83 edges
# 1
# DiGraph with 16 nodes and 78 edges
# 19
# DiGraph with 17 nodes and 84 edges
# 76
# DiGraph with 18 nodes and 108 edges
# 0
# DiGraph with 16 nodes and 91 edges
# 7
# DiGraph with 20 nodes and 118 edges
# 133
# DiGraph with 19 nodes and 101 edges
# 1
# DiGraph with 18 nodes and 111 edges
# 269
# DiGraph with 16 nodes and 77 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 69
# DiGraph with 16 nodes and 83 edges
# 1
# DiGraph with 18 nodes and 92 edges
# 1
# DiGraph with 17 nodes and 91 edges
# 1
# DiGraph with 15 nodes and 71 edges
# 1
# DiGraph with 15 nodes and 58 edges
# 1
# DiGraph with 17 nodes and 91 edges
# 194
# DiGraph with 16 nodes and 75 edges
# 145
# DiGraph with 17 nodes and 89 edges
# 666
# DiGraph with 17 nodes and 103 edges
# 127
# DiGraph with 16 nodes and 87 edges
# 261
# DiGraph with 18 nodes and 93 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 1
# DiGraph with 16 nodes and 86 edges
# 171
# DiGraph with 18 nodes and 102 edges
# 1
# DiGraph with 16 nodes and 91 edges
# 194
# DiGraph with 15 nodes and 62 edges
# 1
# DiGraph with 17 nodes and 101 edges
# 63
# DiGraph with 15 nodes and 68 edges
# 18
# DiGraph with 20 nodes and 126 edges
# 167
# DiGraph with 17 nodes and 88 edges
# 3
# DiGraph with 18 nodes and 111 edges
# 98
# DiGraph with 17 nodes and 98 edges
# 1
# DiGraph with 16 nodes and 87 edges
# 1
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 17 nodes and 92 edges
# 1
# DiGraph with 17 nodes and 95 edges
# 443
# DiGraph with 19 nodes and 106 edges
# 1
# DiGraph with 18 nodes and 89 edges
# 12
# DiGraph with 15 nodes and 70 edges
# 90
# DiGraph with 17 nodes and 80 edges
# 0
# DiGraph with 19 nodes and 116 edges
# 11
# DiGraph with 19 nodes and 117 edges
# 121
# DiGraph with 16 nodes and 81 edges
# 9
# DiGraph with 15 nodes and 75 edges
# 1
# DiGraph with 15 nodes and 72 edges
# 1
# DiGraph with 20 nodes and 121 edges
# 249
# DiGraph with 16 nodes and 81 edges
# 265
# DiGraph with 18 nodes and 103 edges
# 96
# DiGraph with 17 nodes and 77 edges
# 19
# DiGraph with 16 nodes and 83 edges
# 1
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 18 nodes and 108 edges
# 1
# DiGraph with 15 nodes and 75 edges
# 121
# DiGraph with 19 nodes and 108 edges
# 1
# DiGraph with 18 nodes and 102 edges
# 21
# DiGraph with 20 nodes and 115 edges
# 126
# DiGraph with 15 nodes and 64 edges
# 1
# DiGraph with 18 nodes and 113 edges
# 1195
# DiGraph with 19 nodes and 103 edges
# 1
# DiGraph with 19 nodes and 104 edges
# 92
# DiGraph with 20 nodes and 127 edges
# 1
# DiGraph with 17 nodes and 98 edges
# 1
# DiGraph with 16 nodes and 82 edges
# 1
# DiGraph with 20 nodes and 102 edges
# 1
# DiGraph with 18 nodes and 102 edges
# 7
# DiGraph with 19 nodes and 125 edges
# 15
# DiGraph with 19 nodes and 120 edges
# 1
# DiGraph with 16 nodes and 81 edges
# 1
# DiGraph with 19 nodes and 118 edges
# 1
# DiGraph with 19 nodes and 121 edges
# 1
# DiGraph with 18 nodes and 104 edges
# 1
# DiGraph with 18 nodes and 99 edges
# 1
# DiGraph with 20 nodes and 116 edges
# 1
# DiGraph with 16 nodes and 88 edges
# 291
# DiGraph with 18 nodes and 82 edges
# 534
# DiGraph with 16 nodes and 91 edges
# 5
# DiGraph with 19 nodes and 122 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 17 nodes and 80 edges
# 1
# DiGraph with 19 nodes and 117 edges
# 82
# DiGraph with 20 nodes and 143 edges
# 259
# DiGraph with 16 nodes and 84 edges
# 1
# DiGraph with 20 nodes and 108 edges
# 1
# DiGraph with 18 nodes and 112 edges
# 54
# DiGraph with 19 nodes and 120 edges
# 9
# DiGraph with 18 nodes and 110 edges
# 462
# DiGraph with 18 nodes and 106 edges
# 1
# DiGraph with 16 nodes and 70 edges
# 763
# DiGraph with 15 nodes and 66 edges
# 1
# DiGraph with 18 nodes and 104 edges
# 1
# DiGraph with 17 nodes and 80 edges
# 1
# DiGraph with 19 nodes and 105 edges
# 9
# DiGraph with 19 nodes and 107 edges
# 11
# 660
# DiGraph with 16 nodes and 75 edges
# 153
# DiGraph with 20 nodes and 115 edges
# 479
# DiGraph with 18 nodes and 101 edges
# 1
# DiGraph with 19 nodes and 112 edges
# 0
# DiGraph with 20 nodes and 118 edges
# 1
# DiGraph with 20 nodes and 124 edges
# 9
# DiGraph with 18 nodes and 97 edges
# 1
# DiGraph with 20 nodes and 119 edges
# 173
# DiGraph with 16 nodes and 85 edges
# 1
# DiGraph with 18 nodes and 94 edges
# 1
# DiGraph with 16 nodes and 88 edges
# 1
# DiGraph with 19 nodes and 101 edges
# 31
# DiGraph with 19 nodes and 106 edges
# 121
# DiGraph with 18 nodes and 98 edges
# 1
# DiGraph with 17 nodes and 102 edges
# 1
# DiGraph with 16 nodes and 75 edges
# 1
# DiGraph with 18 nodes and 108 edges
# 140
# DiGraph with 15 nodes and 77 edges
# 1
# DiGraph with 20 nodes and 131 edges
# 27
# DiGraph with 17 nodes and 91 edges
# 913
# DiGraph with 19 nodes and 101 edges
# 481
# DiGraph with 17 nodes and 98 edges
# 1
# DiGraph with 16 nodes and 83 edges
# 624
# DiGraph with 17 nodes and 85 edges
# 1
# DiGraph with 20 nodes and 130 edges
# 1
# DiGraph with 17 nodes and 90 edges
# 113
# DiGraph with 20 nodes and 132 edges
# 149
# DiGraph with 17 nodes and 100 edges
# 149
# DiGraph with 15 nodes and 68 edges
# 1
# DiGraph with 17 nodes and 87 edges
# 521
# DiGraph with 16 nodes and 86 edges
# 1
# DiGraph with 15 nodes and 77 edges
# 106
# DiGraph with 16 nodes and 81 edges
# 163
# DiGraph with 20 nodes and 121 edges
# 477
# 63
# DiGraph with 20 nodes and 134 edges
# 3
# DiGraph with 16 nodes and 78 edges
# 5
# DiGraph with 15 nodes and 70 edges
# 399
# DiGraph with 20 nodes and 120 edges
# 60
# DiGraph with 15 nodes and 59 edges
# 34
# DiGraph with 16 nodes and 74 edges
# 1
# DiGraph with 16 nodes and 71 edges
# 1
# DiGraph with 16 nodes and 82 edges
# 1
# DiGraph with 16 nodes and 86 edges
# 1
# 5
# DiGraph with 19 nodes and 103 edges
# 9
# 100
# DiGraph with 19 nodes and 112 edges
# 9
# DiGraph with 18 nodes and 101 edges
# 468
# DiGraph with 15 nodes and 78 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 17 nodes and 78 edges
# 1
# 1541
# DiGraph with 15 nodes and 75 edges
# 509
# DiGraph with 20 nodes and 108 edges
# 7
# DiGraph with 17 nodes and 83 edges
# 1
# DiGraph with 17 nodes and 97 edges
# 11
# DiGraph with 20 nodes and 128 edges
# 1508
# DiGraph with 16 nodes and 79 edges
# 1
# DiGraph with 17 nodes and 97 edges
# 49
# DiGraph with 19 nodes and 118 edges
# 1
# DiGraph with 18 nodes and 106 edges
# 1
# DiGraph with 15 nodes and 74 edges
# 240
# DiGraph with 18 nodes and 101 edges
# 1
# DiGraph with 15 nodes and 69 edges
# 1
# DiGraph with 17 nodes and 100 edges
# 1
# DiGraph with 16 nodes and 76 edges
# 1
# DiGraph with 19 nodes and 109 edges
# 59
# DiGraph with 19 nodes and 114 edges
# 1
# DiGraph with 16 nodes and 63 edges
# 47
# DiGraph with 15 nodes and 62 edges
# 349
# 338
# DiGraph with 16 nodes and 78 edges
# 184
# DiGraph with 17 nodes and 91 edges
# 1
# DiGraph with 15 nodes and 70 edges
# 1
# DiGraph with 19 nodes and 113 edges
# 119
# DiGraph with 16 nodes and 92 edges
# 66
# DiGraph with 18 nodes and 88 edges
# 1
# DiGraph with 16 nodes and 92 edges
# 1
# DiGraph with 18 nodes and 100 edges
# 167
# DiGraph with 18 nodes and 107 edges
# 1
# DiGraph with 16 nodes and 80 edges
# 1
# DiGraph with 20 nodes and 117 edges
# 3
# DiGraph with 19 nodes and 101 edges
# 141
# Generated
